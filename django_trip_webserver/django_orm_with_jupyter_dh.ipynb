# %%
import os, sys
# PWD = os.getenv('PWD')
PWD = os.path.abspath('.')

PROJ_MISSING_MSG = """Set an enviroment variable:\n
`DJANGO_PROJECT=your_project_name`\n
or call:\n
`init_django(your_project_name)`
"""

def init_django(project_name=None):
    os.chdir(PWD)
    project_name = project_name or os.environ.get('DJANGO_PROJECT') or None
    if project_name == None:
        raise Exception(PROJ_MISSING_MSG)
    sys.path.insert(0, os.getenv('PWD'))
    os.environ.setdefault('DJANGO_SETTINGS_MODULE', f'{project_name}.settings')
    os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
    import django
    django.setup()

# %%
init_django('django_trip_webserver') #project name

# %%
from board.models import Trip, TripComment
from main.models import TripCategory, AreaL, AreaM
from user.models import User

# %%
import pandas as pd
import json
import re
df = pd.read_csv('./df_detail.csv', sep=',')
rdf = pd.read_csv('./df_rev.csv', sep=',')

# %%
df.drop(df[df['place_category_group'] == '기타'].index, axis=0, inplace=True)
df = df.reset_index()
df = df.drop(columns = 'index')
df
# Out:
#            trip_name trip_category_detail                trip_address  \
# 0          신라스테이 광화문                신라스테이  서울 종로구 삼봉로 71 G타워 (우)03150
# 1     JW메리어트동대문스퀘어서울               메리어트호텔    서울 종로구 청계천로 279 (우)03198
# 2      이비스앰배서더호텔 인사동               앰배서더호텔  서울 종로구 삼일대로30길 31 (우)03132
# 3             노블관광호텔              베니키아 호텔  서울 종로구 율곡로6길 13-3 (우)03131
# 4          포시즌스호텔 서울                   호텔     서울 종로구 새문안로 97 (우)03183
# ...              ...                  ...                         ...
# 3835     호스텔코리아 창덕궁점                  호스텔       서울 종로구 돈화문로 85 호스텔코리아
# 3836         인사동미니호텔                   모텔    서울 종로구 인사동14길 26 인사동미니호텔
# 3837             숭례문                  기념물               서울 중구 세종대로 40
# 3838            준오호텔                   호텔          서울 종로구 인사동16길 6 2층
# 3839       묘각사 템플스테이                템플스테이            서울 종로구 종로63가길 31
#
#                                              trip_times  \
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                     -
# 4                                      매일 00:00 ~ 24:00
# ...                                                 ...
# 3835                                                  -
# 3836                                                  -
# 3837  ['화: 09:00 - 18:00', '수: 09:00 - 18:00', '목: 0...
# 3838                                                  -
# 3839                                                  -
#
#                                    place_page     trip_phone  \
# 0              www.shillastay.com/gwanghwamun   02-6060-9000
# 1     www.instagram.com/jwmarriott_dongdaemun   02-2276-3000
# 2                   ibis.ambatel.com/insadong   02-6730-1101
# 3                        www.noblehotel.co.kr    02-742-4025
# 4                www.fourseasons.com/kr/seoul   02-6388-5000
# ...                                       ...            ...
# 3835              http://cdg.hostelkorea.com/  070-4705-1900
# 3836                                        -    02-733-1355
# 3837                                        -    02-779-8547
# 3838               http://site.onda.me/133404              -
# 3839                 http://www.myogaksa.net/    02-763-3109
#
#                                            info_content place_category_group
# 0                                                  none                   숙소
# 1                                                  none                   숙소
# 2                                                    주차                   숙소
# 3                                                  none                   숙소
# 4                                                    주차                   숙소
# ...                                                 ...                  ...
# 3835  Hostel Korea 창덕궁 'SAFE STAY away from HOME' 호스...                   숙소
# 3836  인사동 미니호텔은 안국역에서 150m 거리에 있는 미니호텔  게스트하우스 입니다. ...                   숙소
# 3837                                                  -                   관광
# 3838  서울의 중심 종로 인사동에 위치한 종로 준오 호텔입니다   코로나로 잠시 휴식 기간...                   숙소
# 3839   템플스테이 중에는 연락이 안 될 수 있습니다. 전화가 안 될 경우 이메일로 연락 ...                   관광
#
# [3840 rows x 8 columns]

# %%
rdf = rdf.rename(columns={'place_name':'trip_name'})
rdf['comment_star'] = rdf['comment_star'].replace('-', '5.0') # 평점이 없는 것 임의로 5점 줌
rdf['comment_star'] = rdf['comment_star'].astype(float).astype(int)

# %%
rdf['comment_content'] = rdf['comment_content'].replace('-', 'None')
rdf['comment_time']
# Out:
# 0        2023.10.04.
# 1        2023.10.03.
# 2        2023.10.01.
# 3        2023.10.01.
# 4        2023.09.27.
#             ...
# 42136           4년 전
# 42137           2년 전
# 42138           2년 전
# 42139           1년 전
# 42140           1년 전
# Name: comment_time, Length: 42141, dtype: object

# %%
area_large = AreaL(
    area_l_name='서울'
)

area_large.save()

# %%
area_medium = AreaM(
    area_l_id = area_large,
    area_m_name = '종로'
)

area_medium.save()

# %%
trip_category_dic = {'명소':1, '관광':2, '쇼핑':3, '식사':4, '카페':5, '숙소':6}
for i in range(len(df)):
    category_key = df['place_category_group'][i]

    Trip.objects.create(
        trip_category_id = TripCategory.objects.get(id=trip_category_dic[category_key]),
        trip_category_detail = df['trip_category_detail'][i],
        trip_name = df['trip_name'][i],
        trip_address = df['trip_address'][i],
        area_m_id = AreaM.objects.get(id=1),
        trip_time = df['trip_times'][i],
        trip_phone = df['trip_phone'][i],
        trip_homepage = df['place_page'][i],
        is_deleted = False
    )

# %%
from user.models import User

for u in range(len(rdf)):
    User.objects.create(
        user_name = rdf['comment_user'][u],
        user_password = 1234,
        trip_category_1_id = TripCategory.objects.get(id=1),
        trip_category_2_id = TripCategory.objects.get(id=2),
        trip_category_3_id = TripCategory.objects.get(id=3),
        is_deleted = False
    )

# %%
from board.models import Trip, TripComment
from user.models import User

for t in range(len(rdf)):
    trip_instance = Trip.objects.filter(trip_name=rdf['trip_name'][t]).first()
    user_instance = User.objects.filter(user_name=rdf['comment_user'][t]).first()
    TripComment.objects.create(
        user_id=user_instance,
        trip_id=trip_instance,
        trip_comment_content=rdf['comment_content'][t],
        trip_comment_time=rdf['comment_time'][t],
        trip_comment_star=rdf['comment_star'][t],
        is_deleted=False
    )
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\backends\utils.py:89, in CursorWrapper._execute(self, sql, params, *ignored_wrapper_args)
#      88 else:
# ---> 89     return self.cursor.execute(sql, params)
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\backends\mysql\base.py:75, in CursorWrapper.execute(self, query, args)
#      73 try:
#      74     # args is None means no string interpolation
# ---> 75     return self.cursor.execute(query, args)
#      76 except Database.OperationalError as e:
#      77     # Map some error codes to IntegrityError, since they seem to be
#      78     # misclassified and Django would prefer the more logical place.
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\MySQLdb\cursors.py:179, in BaseCursor.execute(self, query, args)
#     178 assert isinstance(mogrified_query, (bytes, bytearray))
# --> 179 res = self._query(mogrified_query)
#     180 return res
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\MySQLdb\cursors.py:330, in BaseCursor._query(self, q)
#     329 self.lastrowid = None
# --> 330 db.query(q)
#     331 self._do_get_result(db)
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\MySQLdb\connections.py:255, in Connection.query(self, query)
#     254     query = bytes(query)
# --> 255 _mysql.connection.query(self, query)
#
# OperationalError: (1366, "Incorrect string value: '\\xF0\\xA5\\x9A\\x83 \\xEB...' for column 'trip_comment_content' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# c:\Users\User\Desktop\git\miniproject_webserver\skku-webproject-git\django_trip_webserver\django_orm_with_jupyter.ipynb Cell 12 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> trip_instance = Trip.objects.filter(trip_name=rdf['trip_name'][t]).first()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> user_instance = User.objects.filter(user_name=rdf['comment_user'][t]).first()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> TripComment.objects.create(
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>     user_id=user_instance,
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a>     trip_id=trip_instance,
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a>     trip_comment_content=rdf['comment_content'][t],
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a>     trip_comment_time=rdf['comment_time'][t],
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a>     trip_comment_star=rdf['comment_star'][t],
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a>     is_deleted=False
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/git/miniproject_webserver/skku-webproject-git/django_trip_webserver/django_orm_with_jupyter.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a> )
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\models\query.py:658, in QuerySet.create(self, **kwargs)
#     656 obj = self.model(**kwargs)
#     657 self._for_write = True
# --> 658 obj.save(force_insert=True, using=self.db)
#     659 return obj
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\models\base.py:814, in Model.save(self, force_insert, force_update, using, update_fields)
#     811     if loaded_fields:
#     812         update_fields = frozenset(loaded_fields)
# --> 814 self.save_base(
#     815     using=using,
#     816     force_insert=force_insert,
#     817     force_update=force_update,
#     818     update_fields=update_fields,
#     819 )
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\models\base.py:877, in Model.save_base(self, raw, force_insert, force_update, using, update_fields)
#     875     if not raw:
#     876         parent_inserted = self._save_parents(cls, using, update_fields)
# --> 877     updated = self._save_table(
#     878         raw,
#     879         cls,
#     880         force_insert or parent_inserted,
#     881         force_update,
#     882         using,
#     883         update_fields,
#     884     )
#     885 # Store the database on which the object was saved
#     886 self._state.db = using
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\models\base.py:1020, in Model._save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#    1017     fields = [f for f in fields if f is not meta.auto_field]
#    1019 returning_fields = meta.db_returning_fields
# -> 1020 results = self._do_insert(
#    1021     cls._base_manager, using, fields, returning_fields, raw
#    1022 )
#    1023 if results:
#    1024     for value, field in zip(results[0], returning_fields):
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\models\base.py:1061, in Model._do_insert(self, manager, using, fields, returning_fields, raw)
#    1056 def _do_insert(self, manager, using, fields, returning_fields, raw):
#    1057     """
#    1058     Do an INSERT. If returning_fields is defined then this method should
#    1059     return the newly created data for the model.
#    1060     """
# -> 1061     return manager._insert(
#    1062         [self],
#    1063         fields=fields,
#    1064         returning_fields=returning_fields,
#    1065         using=using,
#    1066         raw=raw,
#    1067     )
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\models\query.py:1805, in QuerySet._insert(self, objs, fields, returning_fields, raw, using, on_conflict, update_fields, unique_fields)
#    1798 query = sql.InsertQuery(
#    1799     self.model,
#    1800     on_conflict=on_conflict,
#    1801     update_fields=update_fields,
#    1802     unique_fields=unique_fields,
#    1803 )
#    1804 query.insert_values(fields, objs, raw=raw)
# -> 1805 return query.get_compiler(using=using).execute_sql(returning_fields)
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\models\sql\compiler.py:1822, in SQLInsertCompiler.execute_sql(self, returning_fields)
#    1820 with self.connection.cursor() as cursor:
#    1821     for sql, params in self.as_sql():
# -> 1822         cursor.execute(sql, params)
#    1823     if not self.returning_fields:
#    1824         return []
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\backends\utils.py:102, in CursorDebugWrapper.execute(self, sql, params)
#     100 def execute(self, sql, params=None):
#     101     with self.debug_sql(sql, params, use_last_executed_query=True):
# --> 102         return super().execute(sql, params)
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\backends\utils.py:67, in CursorWrapper.execute(self, sql, params)
#      66 def execute(self, sql, params=None):
# ---> 67     return self._execute_with_wrappers(
#      68         sql, params, many=False, executor=self._execute
#      69     )
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\backends\utils.py:80, in CursorWrapper._execute_with_wrappers(self, sql, params, many, executor)
#      78 for wrapper in reversed(self.db.execute_wrappers):
#      79     executor = functools.partial(wrapper, executor)
# ---> 80 return executor(sql, params, many, context)
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\backends\utils.py:84, in CursorWrapper._execute(self, sql, params, *ignored_wrapper_args)
#      82 def _execute(self, sql, params, *ignored_wrapper_args):
#      83     self.db.validate_no_broken_transaction()
# ---> 84     with self.db.wrap_database_errors:
#      85         if params is None:
#      86             # params default might be backend specific.
#      87             return self.cursor.execute(sql)
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\utils.py:91, in DatabaseErrorWrapper.__exit__(self, exc_type, exc_value, traceback)
#      89 if dj_exc_type not in (DataError, IntegrityError):
#      90     self.wrapper.errors_occurred = True
# ---> 91 raise dj_exc_value.with_traceback(traceback) from exc_value
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\backends\utils.py:89, in CursorWrapper._execute(self, sql, params, *ignored_wrapper_args)
#      87     return self.cursor.execute(sql)
#      88 else:
# ---> 89     return self.cursor.execute(sql, params)
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\django\db\backends\mysql\base.py:75, in CursorWrapper.execute(self, query, args)
#      72 def execute(self, query, args=None):
#      73     try:
#      74         # args is None means no string interpolation
# ---> 75         return self.cursor.execute(query, args)
#      76     except Database.OperationalError as e:
#      77         # Map some error codes to IntegrityError, since they seem to be
#      78         # misclassified and Django would prefer the more logical place.
#      79         if e.args[0] in self.codes_for_integrityerror:
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\MySQLdb\cursors.py:179, in BaseCursor.execute(self, query, args)
#     176 mogrified_query = self._mogrify(query, args)
#     178 assert isinstance(mogrified_query, (bytes, bytearray))
# --> 179 res = self._query(mogrified_query)
#     180 return res
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\MySQLdb\cursors.py:330, in BaseCursor._query(self, q)
#     328 self.rowcount = None
#     329 self.lastrowid = None
# --> 330 db.query(q)
#     331 self._do_get_result(db)
#     332 self._post_get_result()
#
# File c:\Users\User\anaconda3\envs\py3.11_jg_trip\Lib\site-packages\MySQLdb\connections.py:255, in Connection.query(self, query)
#     253 if isinstance(query, bytearray):
#     254     query = bytes(query)
# --> 255 _mysql.connection.query(self, query)
#
# OperationalError: (1366, "Incorrect string value: '\\xF0\\xA5\\x9A\\x83 \\xEB...' for column 'trip_comment_content' at row 1")

# %%
'''
오류 나는 이유
1. 파일 경로를 상대 경로로 바꿔야 함
df = pd.read_csv('./df_detail.csv', sep=',')
rdf = pd.read_csv('./df_rev.csv', sep=',')

2. django_orm_with_jupyter.ipynb 즉 이 파일의 경로가
django_trip_webserver 바로 아래 경로에 들어있어야 함

3. trip_time이랑 trip_comment_time이 varchar로 설정되어 있어야 함

4. board > models.py에 trip_comment_time 오타있음

5. user > models.py에 user_id를 Autofiled로 설정해야 함 

++ 아직 설정 못했는데 유니코드 설정 바꿔야함(규현님이 알려주셨는데 까먹음 한번 더 여쭤보기)
'''
# Out:
# "\n오류 나는 이유\n1. 파일 경로를 상대 경로로 바꿔야 함\ndf = pd.read_csv('./df_detail.csv', sep=',')\nrdf = pd.read_csv('./df_rev.csv', sep=',')\n\n2. django_orm_with_jupyter.ipynb 즉 이 파일의 경로가\ndjango_trip_webserver 바로 아래 경로에 들어있어야 함\n\n3. trip_time이랑 trip_comment_time이 varchar로 설정되어 있어야 함\n\n4. board > models.py에 trip_comment_time 오타있음\n\n5. user > models.py에 user_id를 Autofiled로 설정해야 함 \n\n++ 아직 설정 못했는데 유니코드 설정 바꿔야함(규현님이 알려주셨는데 까먹음 한번 더 여쭤보기)\n"
