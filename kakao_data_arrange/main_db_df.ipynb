# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd

# %%
kakao_jongro_acco_data = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_acco_data').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_cafe_data = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_cafe_data.txt').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_gwang_data = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_gwang_data').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_jongro_data = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_jongro_data.txt').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_matjip_data = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_matjip_data').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_shop_data = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_shop_data').drop(columns=['Unnamed: 0'], axis=1)

# %% [markdown]
# --------

# %%
all_kakao_data = pd.concat([kakao_jongro_acco_data, kakao_jongro_cafe_data, kakao_jongro_gwang_data, kakao_jongro_jongro_data, kakao_jongro_matjip_data, kakao_jongro_shop_data], axis=0).reset_index().drop(columns=['index'], axis=1)
all_kakao_data = all_kakao_data.drop_duplicates().reset_index().drop(columns=['index'], axis=1)
all_kakao_data.to_csv('all_kakao_data')
all_kakao_data
# Out:
#           place_name place_category_detail  \
# 0          신라스테이 광화문                 신라스테이
# 1     JW메리어트동대문스퀘어서울                메리어트호텔
# 2      이비스앰배서더호텔 인사동                앰배서더호텔
# 3             노블관광호텔               베니키아 호텔
# 4          포시즌스호텔 서울                    호텔
# ...              ...                   ...
# 2206          빚은 연희점                    빚은
# 2207            충남수산                     회
# 2208            미성까운               단체복,유니폼
# 2209            선진광고                생활용품제조
# 2210           다모아수선                  의류수선
#
#                                      place_adress place_running_date  \
# 0                      서울 종로구 삼봉로 71 G타워 (우)03150                NaN
# 1                        서울 종로구 청계천로 279 (우)03198                NaN
# 2                      서울 종로구 삼일대로30길 31 (우)03132                NaN
# 3                      서울 종로구 율곡로6길 13-3 (우)03131                NaN
# 4                         서울 종로구 새문안로 97 (우)03183   매일 00:00 ~ 24:00
# ...

# %%
# '서울 종로구'로 시작하지 않는 장소 데이터
not_jongro = all_kakao_data[~all_kakao_data['place_adress'].str.startswith('서울 종로구')]
not_jongro[['place_name']]
# Out:
#         place_name
# 1533     종로곱창철판닭갈비
# 1539          종로보쌈
# 1545  본고향맛집 을지로4가점
# 1561          종로곱창
# 1581        종로닭한마리
# ...            ...
# 2206        빚은 연희점
# 2207          충남수산
# 2208          미성까운
# 2209          선진광고
# 2210         다모아수선
#
# [299 rows x 1 columns]

# %%
real_kakao_jongro_data = all_kakao_data[all_kakao_data['place_adress'].str.startswith('서울 종로구')].drop_duplicates().reset_index().drop(columns=['index'])
real_kakao_jongro_data.to_csv('real_kakao_jongro_data')
real_kakao_jongro_data
# Out:
#           place_name place_category_detail  \
# 0          신라스테이 광화문                 신라스테이
# 1     JW메리어트동대문스퀘어서울                메리어트호텔
# 2      이비스앰배서더호텔 인사동                앰배서더호텔
# 3             노블관광호텔               베니키아 호텔
# 4          포시즌스호텔 서울                    호텔
# ...              ...                   ...
# 1907           김현자주단                    한복
# 1908            브러쉬9                    미용
# 1909             성진당                보석,귀금속
# 1910            캣냥닷컴                인터넷쇼핑몰
# 1911          이자인원오원                  액세서리
#
#                                           place_adress place_running_date  \
# 0                           서울 종로구 삼봉로 71 G타워 (우)03150                NaN
# 1                             서울 종로구 청계천로 279 (우)03198                NaN
# 2                           서울 종로구 삼일대로30길 31 (우)03132                NaN
# 3                           서울 종로구 율곡로6길 13-3 (우)03131                NaN
# ...

# %%
kakao_jongro_acco_comment = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_acco_comment_data').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_cafe_comment = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_cafe_comment.txt').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_gwang_comment = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_gwang_comment').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_jongro_comment = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_jongro_comment_data').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_matjip_comment = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_matjip_comment_data').drop(columns=['Unnamed: 0'], axis=1)
kakao_jongro_shop_comment = pd.read_csv('/Users/parkjiyoung/skku-webproject-git/crawl_data_map/kakao_jongro_shop_comment').drop(columns=['Unnamed: 0'], axis=1)

# %%
all_kakao_comment = pd.concat([kakao_jongro_acco_comment, kakao_jongro_cafe_comment, kakao_jongro_gwang_comment, kakao_jongro_jongro_comment, kakao_jongro_matjip_comment, kakao_jongro_shop_comment], axis=0).reset_index().drop(columns=['index'], axis=1)
all_kakao_comment = all_kakao_comment.drop_duplicates().reset_index().drop(columns=['index'])
all_kakao_comment.to_csv('all_kakao_comment')
all_kakao_comment
# Out:
#       place_name place_category_detail         comment_user  comment_star  \
# 0      신라스테이 광화문                 신라스테이                  정도진         100.0
# 1      신라스테이 광화문                 신라스테이                   호야         100.0
# 2      신라스테이 광화문                 신라스테이  김기숙 010 -5305 -2329          80.0
# 3      신라스테이 광화문                 신라스테이                바람난김군         100.0
# 4      신라스테이 광화문                 신라스테이                    .          20.0
# ...          ...                   ...                  ...           ...
# 28925     빚은 연희점                    빚은               tkhsjr          80.0
# 28926       충남수산                     회                  NaN           NaN
# 28927       미성까운               단체복,유니폼                  NaN           NaN
# 28928       선진광고                생활용품제조                  윤사장         100.0
# 28929      다모아수선                  의류수선                  NaN           NaN
#
#       comment_time                 comment_content
# ...

# %%
def change_str_date(date):
    if type(date) != float:
        date = date.rstrip('.')
        date = date.replace('.', '-')
        return date
    else:
        return 'none'

# %%
change_str_date(all_kakao_comment['comment_time'][0])
# Out:
# '2023-10-04'

# %%
type(all_kakao_comment['comment_time'][28929])
# Out:
# float

# %%
# 주소지가 종로인 장소의 댓글
real_kakao_jongro_comment = all_kakao_comment[~all_kakao_comment['place_name'].isin(not_jongro['place_name'])].drop_duplicates().reset_index().drop(columns=['index'])
real_kakao_jongro_comment['comment_time'] = real_kakao_jongro_comment['comment_time'].apply(change_str_date)
real_kakao_jongro_comment.to_csv('real_kakao_jongro_comment')
real_kakao_jongro_comment
# Out:
#       place_name place_category_detail         comment_user  comment_star  \
# 0      신라스테이 광화문                 신라스테이                  정도진         100.0
# 1      신라스테이 광화문                 신라스테이                   호야         100.0
# 2      신라스테이 광화문                 신라스테이  김기숙 010 -5305 -2329          80.0
# 3      신라스테이 광화문                 신라스테이                바람난김군         100.0
# 4      신라스테이 광화문                 신라스테이                    .          20.0
# ...          ...                   ...                  ...           ...
# 27562      김현자주단                    한복                  NaN           NaN
# 27563       브러쉬9                    미용                  NaN           NaN
# 27564        성진당                보석,귀금속                  NaN           NaN
# 27565       캣냥닷컴                인터넷쇼핑몰                  NaN           NaN
# 27566     이자인원오원                  액세서리                  NaN           NaN
#
#       comment_time                 comment_content
# ...

# %%
real_kakao_jongro_comment['comment_time'] = real_kakao_jongro_comment['comment_time'].apply(change_str_date)
real_kakao_jongro_comment
# Out:
#       place_name place_category_detail         comment_user  comment_star  \
# 0      신라스테이 광화문                 신라스테이                  정도진         100.0
# 1      신라스테이 광화문                 신라스테이                   호야         100.0
# 2      신라스테이 광화문                 신라스테이  김기숙 010 -5305 -2329          80.0
# 3      신라스테이 광화문                 신라스테이                바람난김군         100.0
# 4      신라스테이 광화문                 신라스테이                    .          20.0
# ...          ...                   ...                  ...           ...
# 27562      김현자주단                    한복                  NaN           NaN
# 27563       브러쉬9                    미용                  NaN           NaN
# 27564        성진당                보석,귀금속                  NaN           NaN
# 27565       캣냥닷컴                인터넷쇼핑몰                  NaN           NaN
# 27566     이자인원오원                  액세서리                  NaN           NaN
#
#       comment_time                 comment_content
# ...
