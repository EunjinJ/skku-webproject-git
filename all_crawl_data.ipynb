# %%
import pandas as pd
import json

# %%
pd.read_json('/Users/parkjiyoung/skku-webproject-git/goggle_crawl_data/google_jongro_data.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/parkjiyoung/skku-webproject-git/all_crawl_data.ipynb 셀 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/parkjiyoung/skku-webproject-git/all_crawl_data.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> pd.read_json('/Users/parkjiyoung/skku-webproject-git/goggle_crawl_data/google_jongro_data.json')
#
# File ~/anaconda3/envs/tripful/lib/python3.11/site-packages/pandas/io/json/_json.py:784, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     782     return json_reader
#     783 else:
# --> 784     return json_reader.read()
#
# File ~/anaconda3/envs/tripful/lib/python3.11/site-packages/pandas/io/json/_json.py:975, in JsonReader.read(self)
# ...

# %%
pd.read_csv('/Users/parkjiyoung/skku-webproject-git/kakao_data_arrange/all_kakao_comment').drop(columns=['Unnamed: 0'])
# Out:
#       place_name place_category_detail         comment_user  comment_star  \
# 0      신라스테이 광화문                 신라스테이                  정도진         100.0
# 1      신라스테이 광화문                 신라스테이                   호야         100.0
# 2      신라스테이 광화문                 신라스테이  김기숙 010 -5305 -2329          80.0
# 3      신라스테이 광화문                 신라스테이                바람난김군         100.0
# 4      신라스테이 광화문                 신라스테이                    .          20.0
# ...          ...                   ...                  ...           ...
# 28925     빚은 연희점                    빚은               tkhsjr          80.0
# 28926       충남수산                     회                  NaN           NaN
# 28927       미성까운               단체복,유니폼                  NaN           NaN
# 28928       선진광고                생활용품제조                  윤사장         100.0
# 28929      다모아수선                  의류수선                  NaN           NaN
#
#       comment_time                 comment_content
# ...

# %%
pd.read_csv('/Users/parkjiyoung/skku-webproject-git/kakao_data_arrange/all_kakao_data').drop(columns=['Unnamed: 0'])
# Out:
#           place_name place_category_detail  \
# 0          신라스테이 광화문                 신라스테이
# 1     JW메리어트동대문스퀘어서울                메리어트호텔
# 2      이비스앰배서더호텔 인사동                앰배서더호텔
# 3             노블관광호텔               베니키아 호텔
# 4          포시즌스호텔 서울                    호텔
# ...              ...                   ...
# 2206          빚은 연희점                    빚은
# 2207            충남수산                     회
# 2208            미성까운               단체복,유니폼
# 2209            선진광고                생활용품제조
# 2210           다모아수선                  의류수선
#
#                                      place_adress place_running_date  \
# 0                      서울 종로구 삼봉로 71 G타워 (우)03150                NaN
# 1                        서울 종로구 청계천로 279 (우)03198                NaN
# 2                      서울 종로구 삼일대로30길 31 (우)03132                NaN
# 3                      서울 종로구 율곡로6길 13-3 (우)03131                NaN
# 4                         서울 종로구 새문안로 97 (우)03183   매일 00:00 ~ 24:00
# ...
